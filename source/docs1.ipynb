# %% [markdown]
# # Basics

# %%
from manim import *

config.media_embed = True; config.media_width = "100%"
_RV = "-v WARNING -qm --progress_bar None --disable_caching Example"
_RI = "-v WARNING -s --progress_bar None --disable_caching Example"
_RV_mid = "-v WARNING -qm -r 1200,300 --progress_bar None --disable_caching Example"
_RI_mid = "-v WARNING -s -r 1200,300 --progress_bar None --disable_caching Example"
# Out:
# Manim Community v0.17.3

# %%
class Example(Scene):
  def construct(self):
    text = Text("Hello world!").scale(3)
    self.play(Write(text))
    self.wait()

# %manim $_RV
# Out:
# <video controls autoplay style="max-width: 100%;"  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>

# %%
from my_module import MyScene

# %%
class Example(MyScene):
  pass

# %manim $_RV
# Out:
# <video controls autoplay style="max-width: 100%;"  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>

# %% [markdown]
# ## Note, Warning, Hint and Danger
#
# .. note::
#     Hello world
#
# .. warning::
#     Hello world
#
# .. hint::
#     Hello world
#
# .. danger::
#     Hello world
#
# ## Import code
#
# ```py
# print("Hello world!")
# ```
#
# ## Import videos
# ### With directives
#
# .. youtube:: ENMyFGmq5OA
#
# ### With iframe
#
# <iframe width="640" height="360" src="https://www.youtube.com/embed/ENMyFGmq5OA?rel=0" frameborder="0" allowfullscreen></iframe>
